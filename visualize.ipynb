# %%
import pandas as pd

# %%
df=pd.read_csv("population.csv")
df
# Out:
#     Year     Population Yearly %  Change Yearly Change Migrants (net)  \
# 0   2024  1,450,935,791           0.89 %    12,866,195       -630,830
# 1   2023  1,438,069,596           0.89 %    12,646,384       -979,179
# 2   2022  1,425,423,212           0.79 %    11,219,316     -1,353,478
# 3   2020  1,402,617,695           0.98 %    13,587,383        -73,806
# 4   2015  1,328,024,498           1.32 %    16,908,587       -655,085
# 5   2010  1,243,481,564           1.49 %    17,761,048        -50,905
# 6   2005  1,154,676,322           1.77 %    19,350,718       -929,454
# 7   2000  1,057,922,733           1.96 %    19,524,338       -143,960
# 8   1995    960,301,044           2.11 %    19,065,765        -57,297
# 9   1990    864,972,221           2.28 %    18,464,886        125,514
# 10  1985    772,647,793           2.37 %    17,058,754        -89,991
# 11  1980    687,354,025           2.37 %    15,208,898        210,914
# ...

# %%
df["Year"] = df["Year"].astype(int)

# %%
df.set_index("Year",inplace=True)

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#          Population Yearly %  Change Yearly Change Migrants (net)  Median Age  \
# Year
# 1955    387,700,887           2.29 %     8,284,413         70,393        19.7
# 1960    435,990,338           2.38 %     9,657,890        146,955        19.2
# 1965    490,140,146           2.37 %    10,829,962       -248,299        18.5
# 1970    545,864,268           2.18 %    11,144,824        233,782        18.1
# 1975    611,309,535           2.29 %    13,089,053        434,205        18.4
# 1980    687,354,025           2.37 %    15,208,898        210,914        18.9
# 1985    772,647,793           2.37 %    17,058,754        -89,991        19.3
# 1990    864,972,221           2.28 %    18,464,886        125,514        19.7
# 1995    960,301,044           2.11 %    19,065,765        -57,297        20.3
# 2000  1,057,922,733           1.96 %    19,524,338       -143,960        21.2
# 2005  1,154,676,322           1.77 %    19,350,718       -929,454        22.2
# ...

# %%
df["Population"] = df["Population"].str.replace(",", "").astype(float)
df["Urban Population"] = df["Urban Population"].str.replace(",", "").astype(float)
df["World Population"] = df["World Population"].str.replace(",", "").astype(float)
df["Migrants (net)"] = df["Migrants (net)"].str.replace(",", "").astype(float)

# %%
df["Population"].plot(kind="bar",title='Population Growth Over Time', xlabel='Year', ylabel='Population (in billions)')
# Out:
# <AxesSubplot:title={'center':'Population Growth Over Time'}, xlabel='Year', ylabel='Population (in billions)'>

# %%
df[["Population","World Population"]].plot(kind="bar" ,stacked=True,title="World vs India Population Over Years")
# Out:
# <AxesSubplot:title={'center':'World vs India Population Over Years'}, xlabel='Year'>

# %%
df[["Urban Population","Population"]].plot(kind="bar",stacked=True,title='Urban vs Rural Population Over Years')
# Out:
# <AxesSubplot:title={'center':'Urban vs Rural Population Over Years'}, xlabel='Year'>

# %%
df.loc[2024,["Population","World Population"]].plot(kind="pie",title="Percentage of Population in 2024",autopct='%1.1f%%', startangle=90)
# Out:
# <AxesSubplot:title={'center':'Percentage of Population in 2024'}, ylabel='2024'>

# %%
df.loc[2024,["Population","Urban Population"]].plot(kind="pie",title="Percentage of Urban Population in 2024",autopct='%1.1f%%', startangle=90)
# Out:
# <AxesSubplot:title={'center':'Percentage of Urban Population in 2024'}, ylabel='2024'>

# %%
df["Fertility Rate"].plot(title='Fertility Rate Trends Over Time', xlabel='Year', ylabel='Fertility Rate')
# Out:
# <AxesSubplot:title={'center':'Fertility Rate Trends Over Time'}, xlabel='Year', ylabel='Fertility Rate'>

# %%
df['Migrants (net)'].plot(kind='bar', title='Net Migration Trends Over Time', ylabel='Net Migration')
# Out:
# <AxesSubplot:title={'center':'Net Migration Trends Over Time'}, xlabel='Year', ylabel='Net Migration'>
